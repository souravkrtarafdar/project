# %% [markdown]
# assignment 5
# file handling>>>

# %% [markdown]
# # 1.  What is the difference between interpreted and compiled languages?
# >> when source codes all togetherare are directly converted into byte code and then code is run that is called compiled language example- c++,c,java.  but when source codes run line by line unlike compiled languuage that is called interpretered language example- python.
#
#
# 2.What is exception handling in Python?
# >>  exception handling means handling error that may arrive while running a big code and that may stop running the wholeprogramme.
#
# 3. What is the purpose of the finally block in exception handling
# >> finally block contains those codes which will always run whether the try block contains error or not.
#
# 4. What is logging in Python ?
# >>logging means recording steps of a program when it is in running mode example- errors, warnings.
#
# 5.  What is the significance of the __del__ method in Python
# >> del keyword is used to delete variable value or method. __del__ is a special keyword that gets called automatically when del keyword is used in function inatance.
#
# 6.  What is the difference between import and from ... import in Python?
# >> import keyword imports everything from that called module example- import numpy while from and import keyword if used together then imporrt keyword can import specific thing from the called module .example from time import time.

# %% [markdown]
# 7. How can you handle multiple exceptions in Python
# >> using try and except block we can handle multiple exception and under except block we can write multiple exception.
#
# 8. What is the purpose of the with statement when handling files in Python?
# >>with statement automatically closes the the file when the file is called using open() function so donot need to write close() statement.
#
# 9.  What is the difference between multithreading and multiprocessing?
# >> multithreading uses one procesoor and the code get divided into multiple thredas into that processor and all these are run concurrently.
# multiprocessing uses multiple of the cpu and run codes parallaly unlike multithreading.
#
# 10.  What are the advantages of using logging in a program?
# >> logging can save program process in a file that can be later used. we can anlysis error from previous logged file and write better code. very useful for data analysis.
#
# 11. What is memory management in Python?
# >> memory management in python means how python allocating memory and frees memory for the data and objects .
#
# 12. What are the basic steps involved in exception handling in Python?
# >> syntax: try:#code except Exception as e:#code  else:#code  finally:#code
#
# 13.  Why is memory management important in Python?
# >> faster or efficient programming, clean up unnecessary data,
#
# 14. What is the role of try and except in exception handling
# >> try block contains code that may create error while running and except block contains error name and instruction of how to manage that error.
#
# 15. How does Python's garbage collection system work?
# >> python automatically delete that memory which is no longer in use using reference counting method and cyclic garbage collector
#
# 16. What is the purpose of the else block in exception handling?
# >> else block contains those codes which will be run if try block code stays true or there is no error in try block.
#
# 17. What are the common logging levels in Python?
# >> logging levels in python are : debug,info,warning, error, critical.
#
# 18. What is the difference between os.fork() and multiprocessing in >>Pythonok.fork() is a low level system call to create new process while multiprocessing is high level python module for process based parallelism. os.fok() are handelled manully while multiprocessing are handelled automatically.
#
# 19. What is the importance of closing a file in Python?
# >> closing a file is very imprtant because  file will not be updated without closing and no other thing  cannot be done unless that file is opened in that mode   .
#
# 20. What is the difference between file.read() and file.readline() in Python?
# >>read() function shows all the content in the file while readline() function only shows single line.
# 21. What is the logging module in Python used for?
# >> logging module is used to save the process of the program that is in run mode. it includes error, time taken etc.
#
# 22. What is the os module in Python used for in file handling?
# >> os module allow python to deal with operating system like creating folder, changing folder name, deleting folder etc.
#
#  23. What are the challenges associated with memory management in Python
# >> identifying proper garbage, high memory usage of small object, memory leaks.
#
# 24.  How do you raise an exception manually in Python?
# >> we can raise exception by inheriting Exception in a class and using raise keyword we can show what is the error .
#
# 25. Why is it important to use multithreading in certain applications?
# >> some application need same memory space and resources to do a task then there multithreading best suited. example- file downloading, chrome tab.
