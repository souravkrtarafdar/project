# %% [markdown]
# ASSIGNMENT- Python OOPs

# %% [markdown]
# 1. What is Object-Oriented Programming (OOP)
# > OOP is a approach where programs are written using objects that represents real-world entities.
# it helps organise code better and make code reusable without writing.
#
# 2. What is a class in OOP
# > a class is a blueprint or template used to create objects.
# it contains attributes and function .
#
# 3. What is an object in OOP
# > an object is a real instance of a class .it uses class properties and methods.
#
# 4. What is the difference between abstraction and encapsulation
# > abstraction- i. shows what to do ii. focuses on functionality ex- ATM screen.  encapsulation- i. hide how it is done ii. focuses on data security ex- ATM internal code
#
# 5. What are dunder methods in Python
# > special methods with double underscore. they are automatically called by python ex- __init__

# %% [markdown]
# 6. Explain the concept of inheritance in OOP.
# > inheritance allow a class to use the properties of another class . ex- child class class can inherit all the properties and function of parent class.
#
# 7. What is polymorphism in OOP
# > polymorphism means one function many forms means same methods name behaves differently. ex- + method add unmber and also join strings.
#
# 8. How is encapsulation achieved in Python
# > encapsulation is achieved using - double underscore(__) for private variable, single underscore(_) for protected variable, no underscore for public method, using getter and setter methods.
#
# 9. What is a constructor in Python
# > a constructor is a special method used to initialize objects. it runs automatically when an object is created.
#
# 10. What are class and static methods in Python
# > class method uses @classmethod and works with class variable, static method uses @staticmethod and no class or object references.

# %% [markdown]
# 11. What is method overloading in Python
# > methods overloading means same method name with different parameters . python doesnot support traditional overloading.
#
# 12. What is method overriding in OOP
# > method overriding occurs when a child class provides its own implementation of a parent class method.
#
# 13. What is a property decorator in Python
# > the property decorator allows a methods to be accessed like an attribute. it is used to control acces to instance variables.
#
# 14. Why is polymorphism important in OOP
# > polymorphism allows code reuse, improves flexibility, makes program sclable.
#
# 15. What is an abstract class in Python
# > an abstract class is a class tht cannot be instantitead and may contaion abstract methods  . created using ABC module.

# %% [markdown]
# 16. What are the advantages of OOP
# > i. code reusability ii. data security iii. better real world modelling iv. scalibility
#
# 17. What is the difference between a class variable and an instance variable
# > class variable is shared by all objects , defined outside mrthods , uses class name wheresa instance variable is unique to each object , defined inside __init__() and uses self.
#
# 18. What is multiple inheritance in Python
# > multiple inheritance allows a classs to inherit from more than one parent class.
#
# 19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python
# > __str__() is for user friendly output and __repr__() for for developrer/ debugging output. both defines how an object is displayed.
#
# 20. What is the significance of the ‘super()’ function in Python
# > super is used to called parent class methods in a child class so support multiple inheritance and helps avoiding code dublication.

# %% [markdown]
# 21. What is the significance of the __del__ method in Python
# > __del__() is a destructor. it is called when an object is deleted or garbage collected.
#
# 22. What is the difference between @staticmethod and @classmethod in Python
# > in @staticmethod no slef of cls is used, independent of class and it is a utility function whereas @classmethod uses cls , works with class data and it is a factory methods.
#
# 23. How does polymorphism work in Python with inheritance
# > polymorphism works through method overriding . child class provides its own version of a parent classs.
#
# 24. What is method chaining in Python OOP
# > method chaining allows multiple methods to be called i one line. each method returns self.
#
# 25. What is the purpose of the __call__ method in Python?
# > __call__() allows an object to behave like a function . object can be called using ().

# %%
# 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".

class Animal:
  def speak(self):
    print('animal makes sound')
class Dog(Animal):
  def speak(self):
    print('Bark!')

obj= Dog()
obj.speak()
# Out:
# Bark!

# %%
#2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
#from it and implement the area() method in both.
from abc import ABC,abstractmethod
import math

class Shape(ABC):
  @abstractmethod
  def area(self):
    pass
class circle(Shape):
  def __init__(self,r):
    self.r=r
  def area(self):
    return math.pi*self.r*self.r

class Rectangle(Shape):
  def __init__(self,i,b):
    self.i=i
    self.b=b

  def area(self):
    return self.i* self.b

# %%
# 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
#and further derive a class ElectricCar that adds a battery attribute

class Vehicle:
  def __init__(self,type):
    self.type= type

class Car(Vehicle):
  def __init__(self,type,brand):
    super().__init__(type)
    self.brand=brand

class Electriccar(Car):
  def __init__(self,type,brand,battery):
    super().__init__(type,brand)
    self.battery=battery

# %%
#4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.

class Bird:
  def fly(self):
    print("Birds can fly")

class Sparrow(Bird):
  def fly(self):
    print("sparrow flies high")

class Penguin(Bird):
  def fly(self):
    print("penguin cannot fly")

# %%
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance

class BankAccount:
  def __init__(self,balance):
    self.__balance= balance

  def deposit(self,amount):
    self.__balance += amount

  def withdraw(self,amount):
    if amount < self.__balance:
      self.__balance -= amount

  def checkbalance(self):
    return self.__balance

# %%
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().

class Instrument:
  def play(self):
    print("instrument plays ")

class Guiter(Instrument):
  def play(self):
    print("guiter plays")

class Piano(Instrument):
  def play(self):
    print("piano plays")

obj1= Guiter()
obj1.play()

obj2 = Piano()
obj2.play()

# %%
# 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# #method subtract_numbers() to subtract two numbers.

class MathOperations ():
  @classmethod
  def add_numbers(cls,a,b):
    return a+b

  def subtract_numbers(self,a,b):
    return a-b

# %%
# 8. Implement a class Person with a class method to count the total number of persons created.
class Person:
  count = 0
  def __init__(self):
    Person.count += 1
  @classmethod
  def total_person(cls):
    return cls.count

# %%
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".
class Fraction:
  def __init__(self,num,den):
    self.num=num
    self.den=den

  def __str__(self):
    return f"{self.num}/{self.den}"

# %%
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.
class Vector:
  def __init__(self,x,y):
    self.x = x
    self.y=y
  def __add__(self,other):
    return vector(self.x+other.x, self.y+other.y)

# %%
# 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."
class Person:
  def __init__(self, name, age):
    self.name=name
    self.age=age

  def greeet(self):
    print('hello,my name is {self.name} and i am {self.age} years old')

# %%
# 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades
class Students:
  def __init__(self,name,grades):
    self.name=name
    self.grades= grades

  def average_grade(self):
    return sum(self.grades)/len(self.grades)

# %%
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.
class Rectangle:
  def set_dimensions(self,length,breadth):
    self.length=length
    self.breadth=breadth

  def area(self):
    return self.length*self.breadth

# %%
# 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.
class Employee:
  def calculate_salary(self,hour,rate):
    return hour*rate

class Manager(Employee):
  def calculate_salary(self,hour,rate,bonus):
    return super().calculate_salary(hour,rate) + bonus

# %%
# 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.
class Product:
  def total_price(self,name,price,quantity):
    return price*quantity

# %%
# 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.
from abc import ABC,abstractmethod
class Animal(ABC):
  @abstractmethod
  def sound(self):
    pass

class Cow(Animal):
  def sound(self):
    print("cow moo")

class Sheep(Animal):
  def sound(self):
    print("sheep baa")

# %%
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.
class Book:
  def get_book_info(self,title,author,year_published):
    return f"{title} by {author} ({year_published})"

# %%
# 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.
class House:
  def __init__(self,address,price):
    self.address=address
    self.price=price
class Mansion(House):
  def __init__(self,address,price,number_of_rooms):
    super().__init__(address,price)
    self.number_of_rooms=number_of_rooms
