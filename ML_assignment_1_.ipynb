# %% [markdown]
# ### **ML-ASSIGNMENT 1**
# **FEATURE ENGINNERING**

# %% [markdown]
# 1. What is a parameter?
# > Parameters are arguments that takes values as input and without that input, function or method may not run. Parametrs are written in brackets.
#
# 2. What is correlation?
#  What does negative correlation mean?
#  > corelation tells us how two variables are related with each other.It measures whether one variable increases or decreases with changes in another variable.  Negative corelation means if one increases the other one decreases.ex- if more people worked together less time will take to complete a task.
#
#  3. Define Machine Learning. What are the main components in Machine Learning?
#  > Machine learning is a subfield of AI which learn pattern from data and replicate the same without explicitly programmed.main component of machine learning are- data, features ,models, traning,evaluation,deployment.
#
#  4.  How does loss value help in determining whether the model is good or not?
#  > loss tells us whether the model is good or bad and tells how far the prediction is  from truth. 1.if the loss is decreasing then the model is learning 2.if the loss is high and not reducing  the the model is poor.

# %% [markdown]
#  5. What are continuous and categorical variables?
#  > continuous variables are those variables which take numerical vlues- discreate or continuous data as input. whereas categorical variables take categorical valuesa as input .
#
#  6. How do we handle categorical variables in Machine Learning? What are the common techniques?
#  > machine only understands numerical values so categorical values are transformed using encoding. The common techniques are onehot encoding, ordinal encoding,target encoding.
#
#  7. What do you mean by training and testing a dataset?
#  > training datasets are used to train the model sothat itcan find a petten . testing adtasets are unknown or completely new dataset for ML ,used to check whether the model has learned correctly or not.
#
#  8.  What is sklearn.preprocessing?
#  > sklearn or scikit-learn is a library in python while preprocessing is a package in sklearn library . it has many functions to do data preprocessing like polynomialFeatures,oneHotEncoder, ordinalEncoder etc.

# %% [markdown]
# 9. What is a Test set?
# > Test set is  data points which are used to check model accuracy . they are completely new to the model . so the model accuracy will be checked properly.
#
# 10.  How do we split data for model fitting (training and testing) in Python?
#  How do you approach a Machine Learning problem?
#  > to split the data sklearn.model_selection has a function called train_test_split function. with the help of this function we can easily the data into train and test data easily.Trere are lots of steps in solving a ML problem . they are collecting data, cleaning the data, transorm the data,feature enginnering ,split the data , select the model, train the model , evaluate the model, improve the model, deployment.
#
#  11.  Why do we have to perform EDA before fitting a model to the data?
#  > in EDA we look for data distribution , relationships, imbalance in target  . so all these step are very important to create a ggod model.
#
#  12. What is correlation?
#  > corelation tells us how two variables are related with each other.It measures whether one variable increases or decreases with changes in another variable.

# %% [markdown]
# 13. What does negative correlation mean?
# > Negative corelation means if one increases the other one decreases.ex- if more people worked together less time will take to complete a task.
#
# 14. How can you find correlation between variables in Python?
# > to find corelation between features we use filter method in python . by using statistics we can easily found corelation.
#
# 15. What is causation? Explain difference between correlation and causation with an example.
#  > Causation means one event directly causes another events to happen.
#  correlation means two things are related , but not necessarily causes another ex- when ice cream sales increases and car accident decreases.
#  causations means one action directly causes another action to happen .ex- touching fire and burning hands .
#
#  16. What is an Optimizer? What are different types of optimizers? Explain each with an example
#  > optimizer is a method used to adjust models's parameters  so that the loss become as small as possible .
#  different types of optimizer- 1. gredient descent-it updates weights by moving in the direction opposite to the gradient 2. stochastic gradient descent(sgd)-updates weights one example at a time

# %% [markdown]
# 17. What is sklearn.linear_model ?
# > it is a module in scikit-learn that contains all the linear models used for regression,classification.
#
# 18. What does model.fit() do? What arguments must be given?
# > model.fit() is the function  that trains the machine learning model- it learns the pattern from the training data, it adjusts the weights , it reduces the loss. Arguments required- input features, output features are mandatory.
#
# 19. What does model.predict() do? What arguments must be given?
# > model.predict() is used after training to get predictions from the model . for this one arguments is required that is input features .
#
# 20.  What are continuous and categorical variables?
# > continuous variables are those variables which take numerical vlues- discreate or continuous data as input. whereas categorical variables take categorical valuesa as input.
#
# 21. hat is feature scaling? How does it help in Machine Learning?
# > feature scaling means changing the range of numerical features so that all features have same scale.
# model gives more importance to large values so large value features may dominate . scaling brings all the features on scale so no features dominates over another.
#
# 22. How do we perform scaling in Python?
# > to perform scaling we import functions such as MinMaxScaller,StandardScaler from sklearn.preprocessing library. this function bring all the data points either between 0-1 or mean=0 and standard deviation =1.

# %% [markdown]
# 23. what is sklearn.preprocessing?
# >sklearn or scikit-learn is a library in python while preprocessing is a package in sklearn library . it has many functions to do data preprocessing like polynomialFeatures,oneHotEncoder, ordinalEncoder etc.
# 24. How do we split data for model fitting (training and testing) in Python?
# > to split the data sklearn.model_selection has a function called train_test_split function. with the help of this function we can easily the data into train and test data easily.
# 25. Explain data encoding?
# > encoding means changing the categorical data into numerical data because the machine doesnot understand categorical data. ex- "15 years" to only 15.
